# %%
# Plan de Versionado de CITA360

versiones = [
    {"version": "0.0.0", "descripcion": "Lanzamiento Inicial. Se estableció la infraestructura básica del sistema en Google Colab. Configuración de un entorno de trabajo adecuado con Pandas para gestionar las citas en un DataFrame."},
    {"version": "0.1.0", "descripcion": "Funcionalidad de Consultar Citas. Se implementó la funcionalidad para consultar citas mediante la cédula de los usuarios."},
    {"version": "0.2.0", "descripcion": "Confirmar Citas. Se introdujo la funcionalidad de confirmar citas, actualizando el estado de las citas a 'Confirmada'."},
    {"version": "0.2.1", "descripcion": "Mejoras en la Confirmación de Citas. Optimización del proceso de confirmación de citas para no requerir conversiones innecesarias de tipo de dato."},
    {"version": "0.3.0", "descripcion": "Reportes de Citas. Se añadió la opción de generar reportes de citas filtradas por estado: confirmadas, canceladas, modificadas y pendientes."},
    {"version": "0.3.1", "descripcion": "Mejora en la Generación de Reportes. Optimización de la generación de reportes para mejorar el rendimiento con grandes cantidades de datos."},
    {"version": "0.4.0", "descripcion": "Gestión de Usuarios (Administrador). Implementación de la funcionalidad de creación de usuarios (administradores) para gestionar el sistema de citas."},
    {"version": "0.4.1", "descripcion": "Mejoras en la Interfaz de Administrador. Simplificación de las funcionalidades de creación de usuarios y mejora de la interacción con el administrador."},
    {"version": "0.5.0", "descripcion": "Interfaz de Usuario Mejorada. Mejora en las interacciones de la interfaz para consultas y confirmación de citas."},
    {"version": "0.5.1", "descripcion": "Soporte para Variados Tipos de Cédula. Agregado soporte para tipos de cédula en diversos formatos."},
    {"version": "1.0.0", "descripcion": "Lanzamiento Ejecutable. El sistema alcanza su primera versión mayor, con todas las funcionalidades clave implementadas y probadas."}
]

# función para mostrar el plan de versión
def mostrar_plan_versionado():
    print("Plan de Versionado para el Sistema de Gestión de Citas\n")
    for version in versiones:
        print(f"Versión {version['version']} - {version['descripcion']}\n")

# muestro el plan versionado
mostrar_plan_versionado()
# Out:
# Plan de Versionado para el Sistema de Gestión de Citas
#
# Versión 0.0.0 - Lanzamiento Inicial. Se estableció la infraestructura básica del sistema en Google Colab. Configuración de un entorno de trabajo adecuado con Pandas para gestionar las citas en un DataFrame.
#
# Versión 0.1.0 - Funcionalidad de Consultar Citas. Se implementó la funcionalidad para consultar citas mediante la cédula de los usuarios.
#
# Versión 0.2.0 - Confirmar Citas. Se introdujo la funcionalidad de confirmar citas, actualizando el estado de las citas a 'Confirmada'.
#
# Versión 0.2.1 - Mejoras en la Confirmación de Citas. Optimización del proceso de confirmación de citas para no requerir conversiones innecesarias de tipo de dato.
#
# Versión 0.3.0 - Reportes de Citas. Se añadió la opción de generar reportes de citas filtradas por estado: confirmadas, canceladas, modificadas y pendientes.
#
# ...
